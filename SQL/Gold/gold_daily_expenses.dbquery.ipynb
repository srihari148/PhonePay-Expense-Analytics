-- %%
CREATE TABLE ppe.gold.gold_daily_expenses (
  transaction_date DATE,
  year_month STRING,
  category STRING,
  total_amount DOUBLE,
  transaction_count INT,
  debit_amount DOUBLE,
  credit_amount DOUBLE,
  load_ts TIMESTAMP
)
USING DELTA;
