-- %%
CREATE TABLE ppe.silver.silver_transactions (
  transaction_time TIMESTAMP,
  amount DECIMAL(18,2),
  type STRING,
  merchant STRING,
  transaction_id STRING,
  utr STRING,
  paid_by STRING,
  category STRING,
  dq_status STRING,
  dq_reason STRING,
  ingestion_ts TIMESTAMP
)
USING DELTA;
